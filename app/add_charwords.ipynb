# %%
import numpy as np
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import os
import pymongo
from bson.json_util import loads, dumps

# %%
postgres_password = os.environ['POSTGRES_PASSWORD']
mongo_username = os.environ['MONGO_INITDB_ROOT_USERNAME']
mongo_password = os.environ['MONGO_INITDB_ROOT_PASSWORD']
mongo_init_db = os.environ['MONGO_INITDB_DATABASE']

# %%
engine = create_engine("postgresql+psycopg2://{user}:{pw}@postgres:5432/{db}"
                      .format(user="postgres",pw=postgres_password, db="contrans"))

# %%
charwords = pd.read_csv('charwords.csv')

# %%
charwords.to_sql('charwords', con=engine, chunksize=1000, index=False, if_exists='replace')
# Out:
# 5500

# %%
charwords.drop(['Unnamed: 0'], axis=1)
# Out:
#                                word    tf_idf sponsor_id
# 0                     bifia program  0.192886        NaN
# 1                             bifia  0.192886        NaN
# 2                           project  0.177575        NaN
# 3                      secured loan  0.142876        NaN
# 4               assistant secretary  0.129462        NaN
# ...                             ...       ...        ...
# 5495     engaged conduct punishable  0.092499    Z000017
# 5496                           gang  0.090513    Z000017
# 5497              electric vehicles  0.086414    Z000017
# 5498                         bytyqi  0.079694    Z000017
# 5499  club organization association  0.079597    Z000017
#
# [5500 rows x 3 columns]

# %%
myquery = '''
select c.word, c.tf_idf
from charwords c
inner join members m
on c.sponsor_id = m.propublica_id
where m.last_name LIKE '%%CORTEZ'
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#                        word    tf_idf
# 0             climate corps  0.383722
# 1          civilian climate  0.378639
# 2    civilian climate corps  0.378639
# 3                   climate  0.187214
# 4                     corps  0.140386
# 5            public housing  0.135222
# 6                  civilian  0.121353
# 7                   housing  0.116316
# 8           climate service  0.105739
# 9  members civilian climate  0.089262

# %%
myquery = '''
select *
from members
limit 5
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#             title short_title first_name middle_name last_name suffix  \
# 0  Representative        Rep.       Alma        None     ADAMS   None
# 1  Representative        Rep.     Robert          B.  ADERHOLT   None
# 2  Representative        Rep.       Pete        None   AGUILAR   None
# 3  Representative        Rep.       Rick        None     ALLEN   None
# 4  Representative        Rep.      Colin        None    ALLRED   None
#
#    congress chamber    icpsr state  ...                              office  \
# 0     117.0   House  21545.0    NC  ...  2436 Rayburn House Office Building
# 1     117.0   House  29701.0    AL  ...    266 Cannon House Office Building
# 2     117.0   House  21506.0    CA  ...    109 Cannon House Office Building
# 3     117.0   House  21516.0    GA  ...    570 Cannon House Office Building
# 4     117.0   House  21900.0    TX  ...    114 Cannon House Office Building
#
#           phone   fax missed_votes_pct votes_with_party_pct  \
# 0  202-225-1510  None             0.32                99.02
# 1  202-225-4876  None             1.51                96.24
# 2  202-225-3201  None             0.32                98.80
# 3  202-225-2823  None             3.03                90.92
# 4  202-225-2231  None             1.08                98.14
#
#   votes_against_party_pct DWNOMINATE propublica_id  \
# 0                    0.87     -0.465       A000370
# 1                    3.65      0.380       A000055
# 2                    1.09     -0.296       A000371
# 3                    8.97      0.699       A000372
# 4                    1.75     -0.432       A000376
#
#                                  propublica_endpoint  \
# 0  https://api.propublica.org/congress/v1/members...
# 1  https://api.propublica.org/congress/v1/members...
# 2  https://api.propublica.org/congress/v1/members...
# 3  https://api.propublica.org/congress/v1/members...
# 4  https://api.propublica.org/congress/v1/members...
#
#                 last_updated
# 0  2022-11-10 09:30:11 -0500
# 1  2022-11-10 09:30:10 -0500
# 2  2022-11-10 09:30:11 -0500
# 3  2022-11-10 09:30:10 -0500
# 4  2022-11-10 09:30:11 -0500
#
# [5 rows x 36 columns]

# %%
myclient = pymongo.MongoClient(f"mongodb://{mongo_username}:{mongo_password}@mongo:27017/{mongo_init_db}?authSource=admin")

# %%
contrans_db = myclient['contrans']
bills = contrans_db['bills']

# %%
bills.count_documents({})
# Out:
# 17071

# %%
myquery = bills.find({'introduced_date': '2022-11-16'}, 
           {'_id':0, 'short_title':1 , 'sponsor_name':1, 'introduced_date': 1})

# %%
pd.DataFrame.from_records(loads(dumps(myquery)))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
myquery = '''
select * from charwords
limit 5
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#    Unnamed: 0                 word    tf_idf sponsor_id
# 0           0        bifia program  0.192886       None
# 1           1                bifia  0.192886       None
# 2           2              project  0.177575       None
# 3           3         secured loan  0.142876       None
# 4           4  assistant secretary  0.129462       None

# %%
myquery = bills.find({'enacted':{'$ne':None}},
                     {'_id':0, 'enacted':1, 'short_title':1, 'sponsor_name':1})

# %%
laws = pd.DataFrame.from_records(loads(dumps(myquery)))

# %%
loads(dumps(myquery))
# Out:
# [{'short_title': 'Bulk Infant Formula to Retail Shelves Act',
#   'sponsor_name': 'Suzan K. DelBene',
#   'enacted': '2022-10-10'},
#  {'short_title': 'SBIR and STTR Extension Act of 2022',
#   'sponsor_name': 'Benjamin L. Cardin',
#   'enacted': '2022-09-30'},
#  {'short_title': 'A bill to amend section 301 of title 44, United States Code, to establish a term for the appointment of the Director of the Government Publishing Office.',
#   'sponsor_name': 'Roy Blunt',
#   'enacted': '2022-10-17'},
#  {'short_title': "A bill to extend by 19 days the authorization for the special assessment for the Domestic Trafficking Victims' Fund.",
#   'sponsor_name': 'Amy Klobuchar',
#   'enacted': '2022-09-16'},
#  {'short_title': 'To designate the clinic of the Department of Veterans Affairs in Mishawaka, Indiana, as the "Jackie Walorski VA Clinic".',
#   'sponsor_name': 'Jim Banks',
#   'enacted': '2022-09-30'},
#  {'short_title': 'Formula Act',
#   'sponsor_name': 'Earl Blumenauer',
#   'enacted': '2022-07-21'},
#  {'short_title': 'Ensuring the Best Schools for Veterans Act of 2022',
#   'sponsor_name': 'Jon Tester',
#   'enacted': '2022-08-26'},
#  {'short_title': "Veterans' Compensation Cost-of-Living Adjustment Act of 2022",
#   'sponsor_name': 'Elaine Luria',
#   'enacted': '2022-10-10'},
#  {'short_title': 'Access to Baby Formula Act of 2022',
#   'sponsor_name': 'Jahana Hayes',
#   'enacted': '2022-05-21'},
#  {'short_title': 'PAW Act',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2022-10-17'},
#  {'short_title': 'To designate the outpatient clinic of the Department of Veterans Affairs in Ventura, California, as the "Captain Rosemary Bryant Mariner Outpatient Clinic".',
#   'sponsor_name': 'Julia Brownley',
#   'enacted': '2022-10-11'},
#  {'short_title': 'Additional Ukraine Supplemental Appropriations Act, 2022',
#   'sponsor_name': 'Rosa DeLauro',
#   'enacted': '2022-05-21'},
#  {'short_title': 'Supreme Court Police Parity Act of 2022',
#   'sponsor_name': 'John Cornyn',
#   'enacted': '2022-06-16'},
#  {'short_title': 'RECA Extension Act of 2022',
#   'sponsor_name': 'Mike Lee',
#   'enacted': '2022-06-07'},
#  {'short_title': 'Veterans Rapid Retraining Assistance Program Restoration and Recovery Act of 2022',
#   'sponsor_name': 'Richard J. Durbin',
#   'enacted': '2022-06-07'},
#  {'short_title': 'Fiscal Year 2022 Veterans Affairs Major Medical Facility Authorization Act',
#   'sponsor_name': 'Colin Allred',
#   'enacted': '2022-10-10'},
#  {'short_title': 'COVID-19 EIDL Fraud Statute of Limitations Act of 2022',
#   'sponsor_name': 'Blaine Luetkemeyer',
#   'enacted': '2022-08-05'},
#  {'short_title': 'PPP and Bank Fraud Enforcement Harmonization Act of 2022',
#   'sponsor_name': 'Nydia M. Velázquez',
#   'enacted': '2022-08-05'},
#  {'short_title': 'Protection and Advocacy for Voting Access Program Inclusion Act',
#   'sponsor_name': 'Ben Ray Luján',
#   'enacted': '2022-09-30'},
#  {'short_title': 'United States Commission on International Religious Freedom Reauthorization Act of 2022.',
#   'sponsor_name': 'Marco Rubio',
#   'enacted': '2022-09-30'},
#  {'short_title': 'Suspending Normal Trade Relations with Russia and Belarus Act',
#   'sponsor_name': 'Richard E. Neal',
#   'enacted': '2022-04-08'},
#  {'short_title': 'Bankruptcy Threshold Adjustment and Technical Corrections Act',
#   'sponsor_name': 'Charles E. Grassley',
#   'enacted': '2022-06-21'},
#  {'short_title': 'Extension of Continuing Appropriations Act, 2022',
#   'sponsor_name': 'Rosa DeLauro',
#   'enacted': '2022-03-11'},
#  {'short_title': 'Ending Importation of Russian Oil Act',
#   'sponsor_name': 'Lloyd Doggett',
#   'enacted': '2022-04-08'},
#  {'short_title': 'Public Safety Officer Support Act of 2022',
#   'sponsor_name': 'David Trone',
#   'enacted': '2022-08-16'},
#  {'short_title': 'Russia and Belarus SDR Exchange Prohibition Act of 2022',
#   'sponsor_name': 'French Hill',
#   'enacted': '2022-10-04'},
#  {'short_title': 'Making continuing appropriations for fiscal year 2023, and for other purposes.',
#   'sponsor_name': 'Angie Craig',
#   'enacted': '2022-09-30'},
#  {'short_title': 'A bill to provide for the application of certain provisions of the Secure Rural Schools and Community Self-Determination Act of 2000 for fiscal year 2021.',
#   'sponsor_name': 'Michael D. Crapo',
#   'enacted': '2022-03-15'},
#  {'short_title': 'Further Additional Extending Government Funding Act',
#   'sponsor_name': 'Rosa DeLauro',
#   'enacted': '2022-02-18'},
#  {'short_title': 'Ocean Shipping Reform Act of 2022',
#   'sponsor_name': 'Amy Klobuchar',
#   'enacted': '2022-06-16'},
#  {'short_title': 'Ukraine Democracy Defense Lend-Lease Act of 2022',
#   'sponsor_name': 'John Cornyn',
#   'enacted': '2022-05-09'},
#  {'short_title': 'A bill to amend title 38, United States Code, to authorize the Secretary of Veterans Affairs to transfer the name of property of the Department of Veterans Affairs designated by law to other property of the Department.',
#   'sponsor_name': 'Jon Tester',
#   'enacted': '2022-06-07'},
#  {'short_title': 'End Human Trafficking in Government Contracts Act of 2022',
#   'sponsor_name': 'James Lankford',
#   'enacted': '2022-10-17'},
#  {'short_title': 'A bill to include certain computer-related projects in the Federal permitting program under title XLI of the FAST Act, and for other purposes.',
#   'sponsor_name': 'Bill Hagerty',
#   'enacted': '2022-08-16'},
#  {'short_title': 'To ensure that goods made with forced labor in the Xinjiang Uyghur Autonomous Region of the People’s Republic of China do not enter the United States market, and for other purposes.',
#   'sponsor_name': 'Jim McGovern',
#   'enacted': '2021-12-23'},
#  {'short_title': 'A joint resolution joint resolution relating to increasing the debt limit.',
#   'sponsor_name': 'Charles E. Schumer',
#   'enacted': '2021-12-16'},
#  {'short_title': 'Capitol Police Emergency Assistance Act of 2021',
#   'sponsor_name': 'Amy Klobuchar',
#   'enacted': '2021-12-22'},
#  {'short_title': 'Honoring our PACT Act of 2022',
#   'sponsor_name': 'Tim Kaine',
#   'enacted': '2022-08-10'},
#  {'short_title': 'Further Extending Government Funding Act',
#   'sponsor_name': 'Rosa DeLauro',
#   'enacted': '2021-12-03'},
#  {'short_title': "A bill to obtain and direct the placement in the Capitol or on the Capitol Grounds of a statue to honor Associate Justice of the Supreme Court of the United States Sandra Day O'Connor and a statue to honor Associate Justice of the Supreme Court of the Uni",
#   'sponsor_name': 'Amy Klobuchar',
#   'enacted': '2022-04-13'},
#  {'short_title': 'Multinational Species Conservation Funds Semipostal Stamp Reauthorization Act of 2021',
#   'sponsor_name': 'Jim Costa',
#   'enacted': '2022-05-16'},
#  {'short_title': 'Bridging the Gap for New Americans Act',
#   'sponsor_name': 'Amy Klobuchar',
#   'enacted': '2022-10-17'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 1801 Town and Country Drive in Norco, California, as the "Lance Corporal Kareem Nikoui Memorial Post Office Building".',
#   'sponsor_name': 'Ken Calvert',
#   'enacted': '2022-10-11'},
#  {'short_title': 'Further Surface Transportation Extension Act of 2021',
#   'sponsor_name': 'Peter A. DeFazio',
#   'enacted': '2021-10-31'},
#  {'short_title': 'Eliminating Limits to Justice for Child Sex Abuse Victims Act of 2022',
#   'sponsor_name': 'Richard J. Durbin',
#   'enacted': '2022-09-16'},
#  {'short_title': 'Patient Advocate Tracker Act',
#   'sponsor_name': 'Lisa McClain',
#   'enacted': '2022-09-16'},
#  {'short_title': 'Courthouse Ethics and Transparency Act',
#   'sponsor_name': 'John Cornyn',
#   'enacted': '2022-05-13'},
#  {'short_title': 'Shadow Wolves Enhancement Act',
#   'sponsor_name': 'John Katko',
#   'enacted': '2022-04-19'},
#  {'short_title': 'SPEED Recovery Act',
#   'sponsor_name': 'Sam Graves',
#   'enacted': '2022-10-10'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 3900 Crown Road Southwest in Atlanta, Georgia, as the "John R. Lewis Post Office Building".',
#   'sponsor_name': 'Nikema Williams',
#   'enacted': '2022-10-04'},
#  {'short_title': 'REMOTE Act',
#   'sponsor_name': 'David Trone',
#   'enacted': '2021-12-21'},
#  {'short_title': 'Supplemental Impact Aid Flexibility Act',
#   'sponsor_name': 'John Thune',
#   'enacted': '2022-01-21'},
#  {'short_title': 'Bipartisan Safer Communities Act',
#   'sponsor_name': 'Marco Rubio',
#   'enacted': '2022-06-25'},
#  {'short_title': 'Surface Transportation Extension Act of 2021',
#   'sponsor_name': 'Peter A. DeFazio',
#   'enacted': '2021-10-02'},
#  {'short_title': 'Inflation Reduction Act of 2022',
#   'sponsor_name': 'John Yarmuth',
#   'enacted': '2022-08-16'},
#  {'short_title': 'Supporting Families of the Fallen Act',
#   'sponsor_name': 'Tommy Tuberville',
#   'enacted': '2022-10-17'},
#  {'short_title': 'A bill to designate the community-based outpatient clinic of the Department of Veterans Affairs in San Angelo, Texas, as the "Colonel Charles and JoAnne Powell Department of Veterans Affairs Clinic".',
#   'sponsor_name': 'John Cornyn',
#   'enacted': '2022-10-17'},
#  {'short_title': 'Extending Government Funding and Delivering Emergency Assistance Act',
#   'sponsor_name': 'Rosa DeLauro',
#   'enacted': '2021-09-30'},
#  {'short_title': "Reese's Law",
#   'sponsor_name': 'Robin Kelly',
#   'enacted': '2022-08-16'},
#  {'short_title': 'Department of Veterans Affairs Expiring Authorities Act of 2021',
#   'sponsor_name': 'Frank Mrvan',
#   'enacted': '2021-09-30'},
#  {'short_title': 'To award posthumously a Congressional Gold Medal, in commemoration to the servicemembers who perished in Afghanistan on August 26, 2021, during the evacuation of citizens of the United States and Afghan allies at Hamid Karzai International Airport, and fo',
#   'sponsor_name': 'Lisa McClain',
#   'enacted': '2021-12-16'},
#  {'short_title': 'Emergency Repatriation Assistance for Returning Americans Act',
#   'sponsor_name': 'Richard E. Neal',
#   'enacted': '2021-08-31'},
#  {'short_title': 'Strengthening Oversight for Veterans Act of 2021',
#   'sponsor_name': 'Jon Tester',
#   'enacted': '2022-06-07'},
#  {'short_title': 'To amend the Fentanyl Sanctions Act, to modify certain deadlines relating to the Commission on Combating Synthetic Opioid Trafficking.',
#   'sponsor_name': 'David Trone',
#   'enacted': '2021-10-19'},
#  {'short_title': 'Better Cybercrime Metrics Act',
#   'sponsor_name': 'Brian Schatz',
#   'enacted': '2022-05-05'},
#  {'short_title': 'One Stop Shop for Small Business Compliance Act of 2021',
#   'sponsor_name': 'Antonio Delgado',
#   'enacted': '2022-10-10'},
#  {'short_title': 'Making Advances in Mammography and Medical Options for Veterans Act',
#   'sponsor_name': 'Jon Tester',
#   'enacted': '2022-06-07'},
#  {'short_title': 'AI Training Act',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2022-10-17'},
#  {'short_title': 'A bill to rename the Provo Veterans Center in Orem, Utah, as the "Col. Gail S. Halvorsen \'Candy Bomber\' Veterans Center".',
#   'sponsor_name': 'Mike Lee',
#   'enacted': '2022-06-07'},
#  {'short_title': 'State and Local Government Cybersecurity Act of 2021',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2022-06-21'},
#  {'short_title': 'Blackwell School National Historic Site Act',
#   'sponsor_name': 'John Cornyn',
#   'enacted': '2022-10-17'},
#  {'short_title': 'Global Malnutrition Prevention and Treatment Act of 2021',
#   'sponsor_name': 'Michael McCaul',
#   'enacted': '2022-10-19'},
#  {'short_title': 'To designate the Federal Building and United States Courthouse located at 1125 Chapline Street in Wheeling, West Virginia, as the Frederick P. Stamp, Jr. Federal Building and United States Courthouse.',
#   'sponsor_name': 'David McKinley',
#   'enacted': '2021-12-21'},
#  {'short_title': 'VA Electronic Health Record Transparency Act of 2021',
#   'sponsor_name': 'Frank Mrvan',
#   'enacted': '2022-06-23'},
#  {'short_title': 'Ending Forced Arbitration of Sexual Assault and Sexual Harassment Act of 2021',
#   'sponsor_name': 'Cheri Bustos',
#   'enacted': '2022-03-03'},
#  {'short_title': 'Homeland Security for Children Act',
#   'sponsor_name': 'Donald M. Payne Jr.',
#   'enacted': '2022-06-06'},
#  {'short_title': 'Supreme Court Security Funding Act of 2022',
#   'sponsor_name': 'Tim Ryan',
#   'enacted': '2022-08-09'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 6223 Maple Street, in Omaha, Nebraska, as the "Petty Officer 1st Class Charles Jackson French Post Office".',
#   'sponsor_name': 'Don Bacon',
#   'enacted': '2022-06-15'},
#  {'short_title': 'To name the Department of Veterans Affairs community-based outpatient clinic in Aurora, Colorado, as the Lieutenant Colonel John W. Mosley VA Clinic.',
#   'sponsor_name': 'Jason Crow',
#   'enacted': '2021-11-12'},
#  {'short_title': 'CREW Act',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2022-09-29'},
#  {'short_title': 'Supply Chain Security Training Act of 2021',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2022-06-16'},
#  {'short_title': 'Dr. Kate Hendricks Thomas SERVICE Act',
#   'sponsor_name': 'John Boozman',
#   'enacted': '2022-06-07'},
#  {'short_title': 'A bill to designate the Federal Office Building located at 308 W. 21st Street in Cheyenne, Wyoming, as the "Louisa Swain Federal Office Building", and for other purposes.',
#   'sponsor_name': 'Cynthia M. Lummis',
#   'enacted': '2022-05-10'},
#  {'short_title': 'Keep Kids Fed Act of 2022',
#   'sponsor_name': 'Jeanne Shaheen',
#   'enacted': '2022-06-25'},
#  {'short_title': 'Secure Equipment Act of 2021',
#   'sponsor_name': 'Steve Scalise',
#   'enacted': '2021-11-11'},
#  {'short_title': 'To designate the medical center of the Department of Veterans Affairs in San Diego, California, as the Jennifer Moreno Department of Veterans Affairs Medical Center, and to support the designation of a component of such medical center in honor of Kathleen',
#   'sponsor_name': 'Mike Levin',
#   'enacted': '2022-03-14'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 202 Trumbull Street in Saint Clair, Michigan, as the "Corporal Jeffrey Robert Standfest Post Office Building".',
#   'sponsor_name': 'Lisa McClain',
#   'enacted': '2022-06-16'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 200 East Main Street in Maroa, Illinois, as the "Jeremy L. Ridlen Post Office".',
#   'sponsor_name': 'Rodney Davis',
#   'enacted': '2022-06-15'},
#  {'short_title': 'Harlem Hellfighters Congressional Gold Medal Act',
#   'sponsor_name': 'Thomas Suozzi',
#   'enacted': '2021-08-25'},
#  {'short_title': 'United States Army Rangers Veterans of World War II Congressional Gold Medal Act',
#   'sponsor_name': 'Joni Ernst',
#   'enacted': '2022-06-07'},
#  {'short_title': 'K-12 Cybersecurity Act of 2021',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2021-10-08'},
#  {'short_title': 'Major Medical Facility Authorization Act of 2021',
#   'sponsor_name': 'Jon Tester',
#   'enacted': '2021-07-29'},
#  {'short_title': 'To name the Department of Veterans Affairs community-based outpatient clinic in Columbus, Georgia, as the Robert S. Poydasheff VA Clinic.',
#   'sponsor_name': 'Sanford D. Bishop Jr.',
#   'enacted': '2021-11-12'},
#  {'short_title': 'Accelerating Access to Critical Therapies for ALS Act',
#   'sponsor_name': 'Mike Quigley',
#   'enacted': '2021-12-23'},
#  {'short_title': 'Commission To Study the Potential Creation of a National Museum of Asian Pacific American History and Culture Act',
#   'sponsor_name': 'Grace Meng',
#   'enacted': '2022-06-13'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 223 West Chalan Santo Papa in Hagatna, Guam, as the "Atanasio Taitano Perez Post Office".',
#   'sponsor_name': 'Michael San Nicolas',
#   'enacted': '2022-10-11'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 39 West Main Street, in Honeoye Falls, New York, as the "CW4 Christian J. Koch Memorial Post Office".',
#   'sponsor_name': 'Chris Jacobs',
#   'enacted': '2022-10-11'},
#  {'short_title': 'Helping American Victims Afflicted by Neurological Attacks Act of 2021',
#   'sponsor_name': 'Susan Collins',
#   'enacted': '2021-10-08'},
#  {'short_title': 'A bill to designate the community-based outpatient clinic of the Department of Veterans Affairs planned to be built in Oahu, Hawaii, as the "Daniel Kahikina Akaka Department of Veterans Affairs Community-Based Outpatient Clinic".',
#   'sponsor_name': 'Mazie K. Hirono',
#   'enacted': '2022-06-07'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 66 Meserole Avenue in Brooklyn, New York, as the Joseph R. Lentol Post Office.',
#   'sponsor_name': 'Carolyn B. Maloney',
#   'enacted': '2022-03-11'},
#  {'short_title': "Homicide Victims' Families' Rights Act of 2021",
#   'sponsor_name': 'Eric Swalwell',
#   'enacted': '2022-08-03'},
#  {'short_title': 'To award four congressional gold medals to the United States Capitol Police and those who protected the U.S. Capitol on January 6, 2021.',
#   'sponsor_name': 'Nancy Pelosi',
#   'enacted': '2021-08-05'},
#  {'short_title': 'Supporting the Foundation for the National Institutes of Health and the Reagan-Udall Foundation for the Food and Drug Administration Act',
#   'sponsor_name': 'Ben Ray Luján',
#   'enacted': '2022-03-15'},
#  {'short_title': 'Emergency Security Supplemental Appropriations Act, 2021',
#   'sponsor_name': 'Rosa DeLauro',
#   'enacted': '2021-07-30'},
#  {'short_title': 'Safe Sleep for Babies Act of 2021',
#   'sponsor_name': 'Tony Cárdenas',
#   'enacted': '2022-05-16'},
#  {'short_title': 'Save the Liberty Theatre Act of 2021',
#   'sponsor_name': 'Mike Johnson',
#   'enacted': '2022-04-19'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 1905 15th Street in Boulder, Colorado, as the "Officer Eric H. Talley Post Office Building".',
#   'sponsor_name': 'Joe Neguse',
#   'enacted': '2022-03-10'},
#  {'short_title': 'National Defense Authorization Act for Fiscal Year 2022',
#   'sponsor_name': 'Rick Scott',
#   'enacted': '2021-12-27'},
#  {'short_title': 'Modernizing Access to Our Public Land Act',
#   'sponsor_name': 'Blake Moore',
#   'enacted': '2022-04-29'},
#  {'short_title': 'Postal Service Reform Act of 2022',
#   'sponsor_name': 'Carolyn B. Maloney',
#   'enacted': '2022-04-06'},
#  {'short_title': 'STANDUP Act of 2021',
#   'sponsor_name': 'Margaret Hassan',
#   'enacted': '2022-03-15'},
#  {'short_title': 'TBI and PTSD Law Enforcement Training Act',
#   'sponsor_name': 'Bill Pascrell Jr.',
#   'enacted': '2022-08-16'},
#  {'short_title': 'VA Transparency & Trust Act of 2021',
#   'sponsor_name': 'Mike Bost',
#   'enacted': '2021-11-22'},
#  {'short_title': 'COPS Counseling Act',
#   'sponsor_name': 'Catherine Cortez Masto',
#   'enacted': '2021-11-18'},
#  {'short_title': "Protecting America's First Responders Act of 2021",
#   'sponsor_name': 'Charles E. Grassley',
#   'enacted': '2021-11-18'},
#  {'short_title': 'Ghost Army Congressional Gold Medal Act',
#   'sponsor_name': 'Edward J. Markey',
#   'enacted': '2022-02-01'},
#  {'short_title': 'Promoting Physical Activity for Americans Act',
#   'sponsor_name': 'Sherrod Brown',
#   'enacted': '2021-10-14'},
#  {'short_title': 'A bill to amend title 28, United States Code, to redefine the eastern and middle judicial districts of North Carolina.',
#   'sponsor_name': 'Thom Tillis',
#   'enacted': '2021-07-06'},
#  {'short_title': 'A bill to designate the United States courthouse located at 1501 North 6th Street in Harrisburg, Pennsylvania, as the "Sylvia H. Rambo United States Courthouse", and for other purposes.',
#   'sponsor_name': 'Bob Casey',
#   'enacted': '2022-05-10'},
#  {'short_title': 'Solid Start Act of 2022',
#   'sponsor_name': 'Margaret Hassan',
#   'enacted': '2022-10-17'},
#  {'short_title': 'Amache National Historic Site Act',
#   'sponsor_name': 'Joe Neguse',
#   'enacted': '2022-03-18'},
#  {'short_title': 'THRIVE Act',
#   'sponsor_name': 'Mike Levin',
#   'enacted': '2021-06-08'},
#  {'short_title': 'To amend title 38, United States Code, to clarify the role of doctors of podiatric medicine in the Department of Veterans Affairs, and for other purposes.',
#   'sponsor_name': 'Brad Wenstrup',
#   'enacted': '2022-03-14'},
#  {'short_title': 'Federal Rotational Cyber Workforce Program Act of 2021',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2022-06-21'},
#  {'short_title': 'Joint Consolidation Loan Separation Act',
#   'sponsor_name': 'Mark Warner',
#   'enacted': '2022-10-11'},
#  {'short_title': 'Colonel John M. McHugh Tuition Fairness for Survivors Act of 2021',
#   'sponsor_name': 'Jerry Moran',
#   'enacted': '2021-11-30'},
#  {'short_title': 'Consolidated Appropriations Act, 2022',
#   'sponsor_name': 'Hakeem Jeffries',
#   'enacted': '2022-03-15'},
#  {'short_title': 'Sgt. Ketchum Rural Veterans Mental Health Act of 2021',
#   'sponsor_name': 'Cynthia Axne',
#   'enacted': '2021-06-30'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 2800 South Adams Street in Tallahassee, Florida, as the "D. Edwina Stephens Post Office".',
#   'sponsor_name': 'Al Lawson',
#   'enacted': '2022-06-23'},
#  {'short_title': 'To designate the September 11th National Memorial Trail Route, and for other purposes.',
#   'sponsor_name': 'Gerald E. Connolly',
#   'enacted': '2021-10-13'},
#  {'short_title': 'A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Environmental Protection Agency relating to "Oil and Natural Gas Sector: Emission Standards for New, Reconstructed, and',
#   'sponsor_name': 'Martin Heinrich',
#   'enacted': '2021-06-30'},
#  {'short_title': 'A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Office of the Comptroller of Currency relating to "National Banks and Federal Savings Associations as Lenders".',
#   'sponsor_name': 'Chris Van Hollen',
#   'enacted': '2021-06-30'},
#  {'short_title': 'A bill to require the Comptroller General of the United States to conduct a study on disparities associated with race and ethnicity with respect to certain benefits administered by the Secretary of Veterans Affairs, and for other purposes.',
#   'sponsor_name': 'Raphael Warnock',
#   'enacted': '2021-11-30'},
#  {'short_title': 'RENACER Act',
#   'sponsor_name': 'Robert Menendez',
#   'enacted': '2021-11-10'},
#  {'short_title': 'DUMP Opioids Act',
#   'sponsor_name': 'John Kennedy',
#   'enacted': '2021-07-29'},
#  {'short_title': 'Maximizing Outcomes through Better Investments in Lifesaving Equipment for (MOBILE) Health Care Act',
#   'sponsor_name': 'Jacky Rosen',
#   'enacted': '2022-10-17'},
#  {'short_title': 'Jaime Zapata and Victor Avila Federal Officers and Employees Protection Act',
#   'sponsor_name': 'John Cornyn',
#   'enacted': '2021-11-18'},
#  {'short_title': 'COVID-19 Hate Crimes Act',
#   'sponsor_name': 'Mazie K. Hirono',
#   'enacted': '2021-05-20'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 170 Manhattan Avenue in Buffalo, New York, as the "Indiana Hunt-Martin Post Office Building".',
#   'sponsor_name': 'Brian Higgins',
#   'enacted': '2022-10-11'},
#  {'short_title': 'A joint resolution providing for congressional disapproval under chapter 8 of title 5, United States Code, of the rule submitted by the Equal Employment Opportunity Commission relating to "Update of Commission\'s Conciliation Procedures".',
#   'sponsor_name': 'Patty Murray',
#   'enacted': '2021-06-30'},
#  {'short_title': 'Hire Veteran Health Heroes Act of 2021',
#   'sponsor_name': 'Mike Braun',
#   'enacted': '2021-11-30'},
#  {'short_title': 'Veterans and Family Information Act',
#   'sponsor_name': 'Hakeem Jeffries',
#   'enacted': '2021-11-22'},
#  {'short_title': 'Consider Teachers Act of 2021',
#   'sponsor_name': 'Mike Braun',
#   'enacted': '2021-10-13'},
#  {'short_title': 'Methamphetamine Response Act of 2021',
#   'sponsor_name': 'Dianne Feinstein',
#   'enacted': '2022-03-14'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 17 East Main Street in Herington, Kansas, as the Captain Emil J. Kapaun Post Office Building.',
#   'sponsor_name': 'Tracey Mann',
#   'enacted': '2022-03-10'},
#  {'short_title': 'Protecting Moms Who Served Act of 2021',
#   'sponsor_name': 'Tammy Duckworth',
#   'enacted': '2021-11-30'},
#  {'short_title': 'A bill to direct the Secretary of State to develop a strategy to regain observer status for Taiwan in the World Health Organization, and for other purposes.',
#   'sponsor_name': 'Robert Menendez',
#   'enacted': '2022-05-13'},
#  {'short_title': 'Ensuring Compliance Against Drug Diversion Act of 2021',
#   'sponsor_name': 'Morgan Griffith',
#   'enacted': '2021-11-10'},
#  {'short_title': 'To prevent across-the-board direct spending cuts, and for other purposes.',
#   'sponsor_name': 'John Yarmuth',
#   'enacted': '2021-04-14'},
#  {'short_title': 'Harriet Tubman Bicentennial Commemorative Coin Act',
#   'sponsor_name': 'Gregory W. Meeks',
#   'enacted': '2022-08-03'},
#  {'short_title': 'PPP Extension Act of 2021',
#   'sponsor_name': 'Carolyn Bourdeaux',
#   'enacted': '2021-03-30'},
#  {'short_title': 'National Cybersecurity Preparedness Consortium Act of 2021',
#   'sponsor_name': 'John Cornyn',
#   'enacted': '2022-05-12'},
#  {'short_title': 'FTC Collaboration Act of 2021',
#   'sponsor_name': "Tom O'Halleran",
#   'enacted': '2022-10-10'},
#  {'short_title': 'COVID-19 Bankruptcy Relief Extension Act of 2021',
#   'sponsor_name': 'Jerrold Nadler',
#   'enacted': '2021-03-27'},
#  {'short_title': 'VOCA Fix to Sustain the Crime Victims Fund Act of 2021',
#   'sponsor_name': 'Jerrold Nadler',
#   'enacted': '2021-07-22'},
#  {'short_title': 'To authorize the National Medal of Honor Museum Foundation to establish a commemorative work in the District of Columbia and its environs, and for other purposes.',
#   'sponsor_name': 'Marc Veasey',
#   'enacted': '2021-12-27'},
#  {'short_title': 'Dr. Lorna Breen Health Care Provider Protection Act',
#   'sponsor_name': 'Susan Wild',
#   'enacted': '2022-03-18'},
#  {'short_title': 'Protecting Medicare and American Farmers from Sequester Cuts Act',
#   'sponsor_name': 'Tim Kaine',
#   'enacted': '2021-12-10'},
#  {'short_title': 'A bill to designate the facility of the United States Postal Service located at 42 Main Street in Slatersville, Rhode Island, as the "Specialist Matthew R. Turcotte Post Office".',
#   'sponsor_name': 'Jack Reed',
#   'enacted': '2022-02-22'},
#  {'short_title': 'PRICE Act of 2021',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2022-02-22'},
#  {'short_title': 'A bill to make a technical correction to the ALS Disability Insurance Access Act of 2019.',
#   'sponsor_name': 'Mike Braun',
#   'enacted': '2021-03-23'},
#  {'short_title': 'FASTER Act of 2021',
#   'sponsor_name': 'Tim Scott',
#   'enacted': '2021-04-23'},
#  {'short_title': 'To direct the Secretary of Veterans Affairs to submit to Congress a report on the use of cameras in medical facilities of the Department of Veterans Affairs.',
#   'sponsor_name': 'David McKinley',
#   'enacted': '2021-11-23'},
#  {'short_title': 'American Fisheries Advisory Committee Act',
#   'sponsor_name': 'Dan Sullivan',
#   'enacted': '2022-05-12'},
#  {'short_title': 'Advanced Air Mobility Coordination and Leadership Act',
#   'sponsor_name': 'Jerry Moran',
#   'enacted': '2022-10-17'},
#  {'short_title': 'PAWS for Veterans Therapy Act',
#   'sponsor_name': 'Steve Stivers',
#   'enacted': '2021-08-25'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 132 North Loudoun Street, Suite 1 in Winchester, Virginia, as the Patsy Cline Post Office.',
#   'sponsor_name': 'Jennifer Wexton',
#   'enacted': '2022-06-24'},
#  {'short_title': 'BRIGHT Act',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2022-10-17'},
#  {'short_title': "Willie O'Ree Congressional Gold Medal Act",
#   'sponsor_name': 'Debbie Stabenow',
#   'enacted': '2022-01-31'},
#  {'short_title': 'Juneteenth National Independence Day Act',
#   'sponsor_name': 'Edward J. Markey',
#   'enacted': '2021-06-17'},
#  {'short_title': 'Providing for the appointment of Barbara Barrett as a citizen regent of the Board of Regents of the Smithsonian Institution.',
#   'sponsor_name': 'Doris Matsui',
#   'enacted': '2021-06-23'},
#  {'short_title': 'Senate Shared Employee Act',
#   'sponsor_name': 'Amy Klobuchar',
#   'enacted': '2021-04-23'},
#  {'short_title': 'A bill to amend the Federal Food, Drug, and Cosmetic Act with respect to the scope of new chemical exclusivity.',
#   'sponsor_name': 'Bill Cassidy',
#   'enacted': '2021-04-23'},
#  {'short_title': 'To name the Department of Veterans Affairs community-based outpatient clinic in Gaylord, Michigan, as the Navy Corpsman Steve Andrews Department of Veterans Affairs Health Care Clinic.',
#   'sponsor_name': 'Jack Bergman',
#   'enacted': '2022-02-23'},
#  {'short_title': 'American Rescue Plan Act of 2021',
#   'sponsor_name': 'John Yarmuth',
#   'enacted': '2021-03-11'},
#  {'short_title': 'Alaska Tourism Restoration Act',
#   'sponsor_name': 'Don Young',
#   'enacted': '2021-05-24'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 1233 North Cedar Street in Owasso, Oklahoma, as the "Technical Sergeant Marshal Roberts Post Office Building".',
#   'sponsor_name': 'Kevin Hern',
#   'enacted': '2022-06-16'},
#  {'short_title': 'William T. Coleman, Jr. and Norman Y. Mineta Department of Transportation Headquarters Act',
#   'sponsor_name': 'Roger Wicker',
#   'enacted': '2022-05-06'},
#  {'short_title': 'A bill to provide for the availability of amounts for customer education initiatives and non-awards expenses of the Commodity Futures Trading Commission Whistleblower Program, and for other purposes.',
#   'sponsor_name': 'Charles E. Grassley',
#   'enacted': '2021-07-06'},
#  {'short_title': 'Puerto Rico Recovery Accuracy in Disclosures Act of 2021',
#   'sponsor_name': 'Nydia M. Velázquez',
#   'enacted': '2022-01-20'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 1 League in Irvine, California, as the "Tuskegee Airman Lieutenant Colonel Robert J. Friend Memorial Post Office Building".',
#   'sponsor_name': 'Katie Porter',
#   'enacted': '2022-06-23'},
#  {'short_title': 'Greatest Generation Commemorative Coin Act',
#   'sponsor_name': 'Marcy Kaptur',
#   'enacted': '2022-08-03'},
#  {'short_title': 'A bill to amend the Alyce Spotted Bear and Walter Soboleff Commission on Native Children Act to extend the deadline for a report by the Alyce Spotted Bear and Walter Soboleff Commission on Native Children, and for other purposes.',
#   'sponsor_name': 'Lisa Murkowski',
#   'enacted': '2021-09-24'},
#  {'short_title': "'Six Triple Eight' Congressional Gold Medal Act of 2021",
#   'sponsor_name': 'Jerry Moran',
#   'enacted': '2022-03-14'},
#  {'short_title': 'DEBAR Act of 2021',
#   'sponsor_name': 'Robert E. Latta',
#   'enacted': '2021-08-06'},
#  {'short_title': 'TRANSPLANT Act of 2021',
#   'sponsor_name': 'Doris Matsui',
#   'enacted': '2021-05-26'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 3493 Burnet Avenue in Cincinnati, Ohio, as the John H. Leahr and Herbert M. Heilbrun Post Office.',
#   'sponsor_name': 'Brad Wenstrup',
#   'enacted': '2022-03-11'},
#  {'short_title': 'Brown v. Board of Education National Historical Park Expansion and Redesignation Act',
#   'sponsor_name': 'Christopher A. Coons',
#   'enacted': '2022-05-12'},
#  {'short_title': 'Congressional Budget Justification Transparency Act of 2021',
#   'sponsor_name': 'Gary Peters',
#   'enacted': '2021-09-24'},
#  {'short_title': 'Donna M. Doss Memorial Act of 2021',
#   'sponsor_name': 'John Cornyn',
#   'enacted': '2022-05-05'},
#  {'short_title': "Veterans' Compensation Cost-of-Living Adjustment Act of 2021",
#   'sponsor_name': 'John Thune',
#   'enacted': '2021-10-08'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 40 Fulton Street in Middletown, New York, as the "Benjamin A. Gilman Post Office Building".',
#   'sponsor_name': 'Sean Patrick Maloney',
#   'enacted': '2022-06-24'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 229 Minnetonka Avenue South in Wayzata, Minnesota, as the Jim Ramstad Post Office.',
#   'sponsor_name': 'Dean Phillips',
#   'enacted': '2021-08-06'},
#  {'short_title': 'West Los Angeles VA Campus Improvement Act of 2021',
#   'sponsor_name': 'Ted Lieu',
#   'enacted': '2021-06-23'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 502 East Cotati Avenue in Cotati, California, as the "Arturo L. Ibleto Post Office Building".',
#   'sponsor_name': 'Mike Thompson',
#   'enacted': '2022-06-24'},
#  {'short_title': 'Advancing Education on Biosimilars Act of 2021',
#   'sponsor_name': 'Margaret Hassan',
#   'enacted': '2021-04-23'},
#  {'short_title': 'ARTS Act',
#   'sponsor_name': 'Thom Tillis',
#   'enacted': '2022-10-17'},
#  {'short_title': 'Desert Sage Youth Wellness Center Access Improvement Act',
#   'sponsor_name': 'Dianne Feinstein',
#   'enacted': '2022-07-29'},
#  {'short_title': 'A bill to authorize the Seminole Tribe of Florida to lease or transfer certain land, and for other purposes.',
#   'sponsor_name': 'Marco Rubio',
#   'enacted': '2021-11-23'},
#  {'short_title': 'South Florida Clean Coastal Waters Act of 2021',
#   'sponsor_name': 'Marco Rubio',
#   'enacted': '2022-06-16'},
#  {'short_title': 'Expedited Delivery of Airport Infrastructure Act of 2021',
#   'sponsor_name': 'Sam Graves',
#   'enacted': '2022-10-10'},
#  {'short_title': 'To redesignate the Federal building located at 167 North Main Street in Memphis, Tennessee as the "Odell Horton Federal Building".',
#   'sponsor_name': 'Steve Cohen',
#   'enacted': '2021-12-21'},
#  {'short_title': 'To provide for an exception to a limitation against appointment of persons as Secretary of Defense within seven years of relief from active duty as a regular commissioned officer of the Armed Forces.',
#   'sponsor_name': 'Adam Smith',
#   'enacted': '2021-01-22'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 1101 Charlotte Street in Georgetown, South Carolina, as the "Joseph Hayne Rainey Memorial Post Office Building".',
#   'sponsor_name': 'Tom Rice',
#   'enacted': '2021-08-06'},
#  {'short_title': 'John Lewis NIMHD Research Endowment Revitalization Act of 2021',
#   'sponsor_name': 'Nanette Barragán',
#   'enacted': '2022-03-18'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 500 West Main Street, Suite 102 in Tupelo, Mississippi, as the Colonel Carlyle Smitty Harris Post Office.',
#   'sponsor_name': 'Trent Kelly',
#   'enacted': '2021-08-06'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 810 South Pendleton Street in Easley, South Carolina, as the "Private First Class Barrett Lyle Austin Post Office Building".',
#   'sponsor_name': 'Jeffrey Duncan',
#   'enacted': '2022-10-11'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 110 Johnson Street in Pickens, South Carolina, as the "Specialist Four Charles Johnson Post Office".',
#   'sponsor_name': 'Jeffrey Duncan',
#   'enacted': '2022-10-11'},
#  {'short_title': 'Construction Consensus Procurement Improvement Act of 2021',
#   'sponsor_name': 'James Comer',
#   'enacted': '2021-07-26'},
#  {'short_title': 'To designate the National Pulse Memorial located at 1912 South Orange Avenue, Orlando, Florida, 32806, and for other purposes.',
#   'sponsor_name': 'Darren Soto',
#   'enacted': '2021-06-25'},
#  {'short_title': 'Emmett Till Antilynching Act',
#   'sponsor_name': 'Bobby L. Rush',
#   'enacted': '2022-03-29'}]
