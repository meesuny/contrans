# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
nba = pd.read_csv('https://raw.githubusercontent.com/jkropko/contrans/main/examples/ASA%20All%20NBA%20Raw%20Data.csv')

# %%
nba.columns
# Out:
# Index(['game_id', 'game_date', 'OT', 'H_A', 'Team_Abbrev', 'Team_Score',
#        'Team_pace', 'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct',
#        'Team_ft_rate', 'Team_off_rtg', 'Inactives', 'Opponent_Abbrev',
#        'Opponent_Score', 'Opponent_pace', 'Opponent_efg_pct',
#        'Opponent_tov_pct', 'Opponent_orb_pct', 'Opponent_ft_rate',
#        'Opponent_off_rtg', 'player', 'player_id', 'starter', 'mp', 'fg', 'fga',
#        'fg_pct', 'fg3', 'fg3a', 'fg3_pct', 'ft', 'fta', 'ft_pct', 'orb', 'drb',
#        'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts', 'plus_minus',
#        'did_not_play', 'is_inactive', 'ts_pct', 'efg_pct', 'fg3a_per_fga_pct',
#        'fta_per_fga_pct', 'orb_pct', 'drb_pct', 'trb_pct', 'ast_pct',
#        'stl_pct', 'blk_pct', 'tov_pct', 'usg_pct', 'off_rtg', 'def_rtg', 'bpm',
#        'season', 'minutes', 'double_double', 'triple_double', 'DKP', 'FDP',
#        'SDP', 'DKP_per_minute', 'FDP_per_minute', 'SDP_per_minute',
#        'pf_per_minute', 'ts', 'last_60_minutes_per_game_starting',
#        'last_60_minutes_per_game_bench', 'PG%', 'SG%', 'SF%', 'PF%', 'C%',
#        'active_position_minutes'],
#       dtype='object')

# %%
nba = nba[['game_id', 'game_date', 'OT', 'H_A', 'Team_Abbrev', 'Team_Score',
       'Team_pace', 'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct',
       'Team_ft_rate', 'Team_off_rtg', 'Inactives', 'Opponent_Abbrev',
       'player', 'player_id', 'starter', 'mp', 'fg', 'fga',
       'fg_pct', 'fg3', 'fg3a', 'fg3_pct', 'ft', 'fta', 'ft_pct', 'orb', 'drb',
       'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts', 'plus_minus',
       'did_not_play', 'is_inactive', 'off_rtg', 'def_rtg', 'bpm']]

# %%
pd.set_option('display.max_rows',90)
nba.head(3).T
# Out:
#                                                                  0  \
# game_id                                               202204100BRK
# game_date                                               2022-04-10
# OT                                                               0
# H_A                                                              A
# Team_Abbrev                                                    IND
# Team_Score                                                     126
# Team_pace                                                    103.9
# Team_efg_pct                                                 0.543
# Team_tov_pct                                                   5.9
# Team_orb_pct                                                  20.8
# Team_ft_rate                                                 0.125
# Team_off_rtg                                                 121.3
# Inactives        Chris Duarte, Nate Hinton, Ricky Rubio, Myles ...
# Opponent_Abbrev                                                BRK
# player                                           Tyrese Haliburton
# player_id                                                halibty01
# starter                                                          1
# mp                                                           39:28
# fg                                                               7
# fga                                                             14
# fg_pct                                                         0.5
# fg3                                                              2
# fg3a                                                             5
# fg3_pct                                                        0.4
# ft                                                               1
# fta                                                              1
# ft_pct                                                         1.0
# orb                                                              2
# drb                                                              2
# trb                                                              4
# ast                                                             10
# stl                                                              2
# blk                                                              0
# tov                                                              1
# pf                                                               0
# pts                                                             17
# plus_minus                                                      -9
# did_not_play                                                     0
# is_inactive                                                      0
# off_rtg                                                        137
# def_rtg                                                        132
# bpm                                                            1.7
#
#                                                                  1  \
# game_id                                               202204100BRK
# game_date                                               2022-04-10
# OT                                                               0
# H_A                                                              A
# Team_Abbrev                                                    IND
# Team_Score                                                     126
# Team_pace                                                    103.9
# Team_efg_pct                                                 0.543
# Team_tov_pct                                                   5.9
# Team_orb_pct                                                  20.8
# Team_ft_rate                                                 0.125
# Team_off_rtg                                                 121.3
# Inactives        Chris Duarte, Nate Hinton, Ricky Rubio, Myles ...
# Opponent_Abbrev                                                BRK
# player                                                 Buddy Hield
# player_id                                                hieldbu01
# starter                                                          1
# mp                                                           35:53
# fg                                                               8
# fga                                                             23
# fg_pct                                                       0.348
# fg3                                                              5
# fg3a                                                            14
# fg3_pct                                                      0.357
# ft                                                               0
# fta                                                              0
# ft_pct                                                         0.0
# orb                                                              0
# drb                                                              3
# trb                                                              3
# ast                                                              6
# stl                                                              3
# blk                                                              0
# tov                                                              2
# pf                                                               3
# pts                                                             21
# plus_minus                                                       0
# did_not_play                                                     0
# is_inactive                                                      0
# off_rtg                                                         94
# def_rtg                                                        128
# bpm                                                           -2.3
#
#                                                                  2
# game_id                                               202204100BRK
# game_date                                               2022-04-10
# OT                                                               0
# H_A                                                              A
# Team_Abbrev                                                    IND
# Team_Score                                                     126
# Team_pace                                                    103.9
# Team_efg_pct                                                 0.543
# Team_tov_pct                                                   5.9
# Team_orb_pct                                                  20.8
# Team_ft_rate                                                 0.125
# Team_off_rtg                                                 121.3
# Inactives        Chris Duarte, Nate Hinton, Ricky Rubio, Myles ...
# Opponent_Abbrev                                                BRK
# player                                              Oshae Brissett
# player_id                                                brissos01
# starter                                                          1
# mp                                                           35:47
# fg                                                              10
# fga                                                             20
# fg_pct                                                         0.5
# fg3                                                              5
# fg3a                                                            10
# fg3_pct                                                        0.5
# ft                                                               3
# fta                                                              4
# ft_pct                                                        0.75
# orb                                                              3
# drb                                                              5
# trb                                                              8
# ast                                                              3
# stl                                                              1
# blk                                                              0
# tov                                                              0
# pf                                                               5
# pts                                                             28
# plus_minus                                                      -9
# did_not_play                                                     0
# is_inactive                                                      0
# off_rtg                                                        137
# def_rtg                                                        133
# bpm                                                            4.4

# %% [markdown]
# ## First normal form.
#
# Every table has a primary key?  Yes.
#
# Non-atomic data?  Yes, Inactives.  But this is redundant, so we just delete this column.
#
# Repeating groups?  Not anymore!
#
# So we have first normal form relational database!  Yay!

# %%
nba = nba.drop(['Inactives'],axis=1)
nba.head(3).T
# Out:
#                                  0             1               2
# game_id               202204100BRK  202204100BRK    202204100BRK
# game_date               2022-04-10    2022-04-10      2022-04-10
# OT                               0             0               0
# H_A                              A             A               A
# Team_Abbrev                    IND           IND             IND
# Team_Score                     126           126             126
# Team_pace                    103.9         103.9           103.9
# Team_efg_pct                 0.543         0.543           0.543
# Team_tov_pct                   5.9           5.9             5.9
# Team_orb_pct                  20.8          20.8            20.8
# Team_ft_rate                 0.125         0.125           0.125
# Team_off_rtg                 121.3         121.3           121.3
# Opponent_Abbrev                BRK           BRK             BRK
# player           Tyrese Haliburton   Buddy Hield  Oshae Brissett
# player_id                halibty01     hieldbu01       brissos01
# starter                          1             1               1
# mp                           39:28         35:53           35:47
# fg                               7             8              10
# fga                             14            23              20
# fg_pct                         0.5         0.348             0.5
# fg3                              2             5               5
# fg3a                             5            14              10
# fg3_pct                        0.4         0.357             0.5
# ft                               1             0               3
# fta                              1             0               4
# ft_pct                         1.0           0.0            0.75
# orb                              2             0               3
# drb                              2             3               5
# trb                              4             3               8
# ast                             10             6               3
# stl                              2             3               1
# blk                              0             0               0
# tov                              1             2               0
# pf                               0             3               5
# pts                             17            21              28
# plus_minus                      -9             0              -9
# did_not_play                     0             0               0
# is_inactive                      0             0               0
# off_rtg                        137            94             137
# def_rtg                        132           128             133
# bpm                            1.7          -2.3             4.4

# %% [markdown]
# ## Second normal form.
#
# Is the data in first normal form (1NF)?  Yup!
#
# Every non-prime column must depend on the ENTIRE primary key (game_id + player_id) and not just part of the primary key (just game_id or just player_id).  (i.e., can't have attributes that are functionally dependent on *part* of a primary key)  right now, we have non-prime attributes that depend on the game but not the player; this needs to be resolved before we can proceed.

# %%
nba['game_player_id'] = nba['game_id'] + '_' + nba['player_id']
nba.head(3).T
# Out:
#                                       0                       1  \
# game_id                    202204100BRK            202204100BRK
# game_date                    2022-04-10              2022-04-10
# OT                                    0                       0
# H_A                                   A                       A
# Team_Abbrev                         IND                     IND
# Team_Score                          126                     126
# Team_pace                         103.9                   103.9
# Team_efg_pct                      0.543                   0.543
# Team_tov_pct                        5.9                     5.9
# Team_orb_pct                       20.8                    20.8
# Team_ft_rate                      0.125                   0.125
# Team_off_rtg                      121.3                   121.3
# Opponent_Abbrev                     BRK                     BRK
# player                Tyrese Haliburton             Buddy Hield
# player_id                     halibty01               hieldbu01
# starter                               1                       1
# mp                                39:28                   35:53
# fg                                    7                       8
# fga                                  14                      23
# fg_pct                              0.5                   0.348
# fg3                                   2                       5
# fg3a                                  5                      14
# fg3_pct                             0.4                   0.357
# ft                                    1                       0
# fta                                   1                       0
# ft_pct                              1.0                     0.0
# orb                                   2                       0
# drb                                   2                       3
# trb                                   4                       3
# ast                                  10                       6
# stl                                   2                       3
# blk                                   0                       0
# tov                                   1                       2
# pf                                    0                       3
# pts                                  17                      21
# plus_minus                           -9                       0
# did_not_play                          0                       0
# is_inactive                           0                       0
# off_rtg                             137                      94
# def_rtg                             132                     128
# bpm                                 1.7                    -2.3
# game_player_id   202204100BRK_halibty01  202204100BRK_hieldbu01
#
#                                       2
# game_id                    202204100BRK
# game_date                    2022-04-10
# OT                                    0
# H_A                                   A
# Team_Abbrev                         IND
# Team_Score                          126
# Team_pace                         103.9
# Team_efg_pct                      0.543
# Team_tov_pct                        5.9
# Team_orb_pct                       20.8
# Team_ft_rate                      0.125
# Team_off_rtg                      121.3
# Opponent_Abbrev                     BRK
# player                   Oshae Brissett
# player_id                     brissos01
# starter                               1
# mp                                35:47
# fg                                   10
# fga                                  20
# fg_pct                              0.5
# fg3                                   5
# fg3a                                 10
# fg3_pct                             0.5
# ft                                    3
# fta                                   4
# ft_pct                             0.75
# orb                                   3
# drb                                   5
# trb                                   8
# ast                                   3
# stl                                   1
# blk                                   0
# tov                                   0
# pf                                    5
# pts                                  28
# plus_minus                           -9
# did_not_play                          0
# is_inactive                           0
# off_rtg                             137
# def_rtg                             133
# bpm                                 4.4
# game_player_id   202204100BRK_brissos01

# %% [markdown]
# Now that we've created game_player_id that is the primary key, we're now good on 2NF.

# %% [markdown]
# ## Third normal form.
#
# Data is in 2NF.
#
# Every non-prime attribute is non-transitively dependent on every attribute.  (i.e., no transitive dependencies between/amongst non-primary keys)
#
# Calculated columns:
# - fg_pct
# - fg3_pct
# - ft_pct
# - trb
# We will delete these.

# %%
nba = nba.drop(['fg_pct','fg3_pct','ft_pct','trb'],axis=1)

# %%
nba.head(6).T
# Out:
#                                       0                       1  \
# game_id                    202204100BRK            202204100BRK
# game_date                    2022-04-10              2022-04-10
# OT                                    0                       0
# H_A                                   A                       A
# Team_Abbrev                         IND                     IND
# Team_Score                          126                     126
# Team_pace                         103.9                   103.9
# Team_efg_pct                      0.543                   0.543
# Team_tov_pct                        5.9                     5.9
# Team_orb_pct                       20.8                    20.8
# Team_ft_rate                      0.125                   0.125
# Team_off_rtg                      121.3                   121.3
# Opponent_Abbrev                     BRK                     BRK
# player                Tyrese Haliburton             Buddy Hield
# player_id                     halibty01               hieldbu01
# starter                               1                       1
# mp                                39:28                   35:53
# fg                                    7                       8
# fga                                  14                      23
# fg3                                   2                       5
# fg3a                                  5                      14
# ft                                    1                       0
# fta                                   1                       0
# orb                                   2                       0
# drb                                   2                       3
# ast                                  10                       6
# stl                                   2                       3
# blk                                   0                       0
# tov                                   1                       2
# pf                                    0                       3
# pts                                  17                      21
# plus_minus                           -9                       0
# did_not_play                          0                       0
# is_inactive                           0                       0
# off_rtg                             137                      94
# def_rtg                             132                     128
# bpm                                 1.7                    -2.3
# game_player_id   202204100BRK_halibty01  202204100BRK_hieldbu01
#
#                                       2                       3  \
# game_id                    202204100BRK            202204100BRK
# game_date                    2022-04-10              2022-04-10
# OT                                    0                       0
# H_A                                   A                       A
# Team_Abbrev                         IND                     IND
# Team_Score                          126                     126
# Team_pace                         103.9                   103.9
# Team_efg_pct                      0.543                   0.543
# Team_tov_pct                        5.9                     5.9
# Team_orb_pct                       20.8                    20.8
# Team_ft_rate                      0.125                   0.125
# Team_off_rtg                      121.3                   121.3
# Opponent_Abbrev                     BRK                     BRK
# player                   Oshae Brissett          Isaiah Jackson
# player_id                     brissos01               jacksis01
# starter                               1                       1
# mp                                35:47                   32:01
# fg                                   10                       3
# fga                                  20                       4
# fg3                                   5                       0
# fg3a                                 10                       0
# ft                                    3                       1
# fta                                   4                       2
# orb                                   3                       0
# drb                                   5                       3
# ast                                   3                       0
# stl                                   1                       2
# blk                                   0                       1
# tov                                   0                       2
# pf                                    5                       5
# pts                                  28                       7
# plus_minus                           -9                       3
# did_not_play                          0                       0
# is_inactive                           0                       0
# off_rtg                             137                      89
# def_rtg                             133                     128
# bpm                                 4.4                    -9.2
# game_player_id   202204100BRK_brissos01  202204100BRK_jacksis01
#
#                                       4                       5
# game_id                    202204100BRK            202204100BRK
# game_date                    2022-04-10              2022-04-10
# OT                                    0                       0
# H_A                                   A                       A
# Team_Abbrev                         IND                     IND
# Team_Score                          126                     126
# Team_pace                         103.9                   103.9
# Team_efg_pct                      0.543                   0.543
# Team_tov_pct                        5.9                     5.9
# Team_orb_pct                       20.8                    20.8
# Team_ft_rate                      0.125                   0.125
# Team_off_rtg                      121.3                   121.3
# Opponent_Abbrev                     BRK                     BRK
# player                   T.J. McConnell            Terry Taylor
# player_id                     mccontj01               taylote01
# starter                               1                       0
# mp                                30:52                   23:37
# fg                                    5                       4
# fga                                  15                       7
# fg3                                   3                       0
# fg3a                                  7                       1
# ft                                    1                       2
# fta                                   2                       2
# orb                                   0                       6
# drb                                   3                       1
# ast                                   5                       1
# stl                                   3                       1
# blk                                   0                       0
# tov                                   0                       0
# pf                                    3                       2
# pts                                  14                      10
# plus_minus                            7                     -12
# did_not_play                          0                       0
# is_inactive                           0                       0
# off_rtg                             104                     158
# def_rtg                             126                     133
# bpm                                -1.7                    -0.7
# game_player_id   202204100BRK_mccontj01  202204100BRK_taylote01

# %% [markdown]
# Transitive dependencies:
# - Some columns depend on player
# - Some columns depend on game
# - Some columns depend on the team
# - Some columns depend on the team + game (e.g., team score)
#
# Each of these will get a separate table.

# %%
nba_teamgame = nba[['game_id','H_A', 'Team_Abbrev', 'Team_Score',
       'Team_pace', 'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct',
       'Team_ft_rate', 'Team_off_rtg', 'Opponent_Abbrev']]
nba_teamgame = nba_teamgame.drop_duplicates()

# %%
nba_teamgame
# Out:
#             game_id H_A Team_Abbrev  Team_Score  Team_pace  Team_efg_pct  \
# 0      202204100BRK   A         IND         126      103.9         0.543
# 12     202204100BRK   H         BRK         134      103.9         0.691
# 25     202204100CHO   A         WAS         108       97.7         0.489
# 37     202204100CHO   H         CHO         124       97.7         0.640
# 52     202204100CLE   A         MIL         115      101.9         0.511
# ...             ...  ..         ...         ...        ...           ...
# 21491  202112190MIN   H         MIN         111       91.8         0.565
# 21492  202112210DAL   A         MIN         102       93.9         0.538
# 21629  202112280MIN   H         MIN          88       93.1         0.441
# 21708  202112230UTA   A         MIN         116      102.1         0.530
# 21709  202112270MIN   H         MIN         108       99.0         0.522
#
#        Team_tov_pct  Team_orb_pct  Team_ft_rate  Team_off_rtg Opponent_Abbrev
# 0               5.9          20.8         0.125         121.3             BRK
# 12             17.9          29.6         0.272         129.0             IND
# 25              8.7          31.5         0.170         110.5             CHO
# 37             15.2          29.7         0.112         126.9             WAS
# 52             10.5          17.4         0.284         112.9             CLE
# ...             ...           ...           ...           ...             ...
# 21491           9.0          15.0         0.312         120.9             DAL
# 21492          16.2          20.9         0.215         108.6             DAL
# 21629           9.6          20.4         0.153          94.5             NYK
# 21708          11.6          30.0         0.089         113.7             UTA
# 21709          12.5          22.4         0.156         109.1             BOS
#
# [2460 rows x 11 columns]

# %%
nba_game = nba[['game_id','game_date','OT']].drop_duplicates()
nba_game
# Out:
#             game_id   game_date  OT
# 0      202204100BRK  2022-04-10   0
# 25     202204100CHO  2022-04-10   0
# 52     202204100CLE  2022-04-10   0
# 77     202204100DAL  2022-04-10   0
# 103    202204100DEN  2022-04-10   1
# ...             ...         ...  ..
# 19708  202110300MIN  2021-10-30   0
# 19726  202112150DEN  2021-12-15   0
# 19748  202202010MIN  2022-02-01   0
# 20615  202203270BOS  2022-03-27   0
# 20679  202112270MIN  2021-12-27   0
#
# [1230 rows x 3 columns]

# %%
nba_player = nba[['player_id','player']].drop_duplicates()
nba_player
# Out:
#        player_id             player
# 0      halibty01  Tyrese Haliburton
# 1      hieldbu01        Buddy Hield
# 2      brissos01     Oshae Brissett
# 3      jacksis01     Isaiah Jackson
# 4      mccontj01     T.J. McConnell
# ...          ...                ...
# 31515  garrema01     Marcus Garrett
# 31535  chalmma01     Mario Chalmers
# 31538  holmaar01        Aric Holman
# 31540  scrubja01         Jay Scrubb
# 31590  prestja01      Jason Preston
#
# [621 rows x 2 columns]

# %%
nba_playergame = nba.drop(['player','game_date','OT','H_A', 'Team_Abbrev', 'Team_Score',
       'Team_pace', 'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct',
       'Team_ft_rate', 'Team_off_rtg', 'Opponent_Abbrev'],axis=1)

# %%
nba_playergame
# Out:
#             game_id  player_id  starter     mp  fg  fga  fg3  fg3a  ft  fta  \
# 0      202204100BRK  halibty01        1  39:28   7   14    2     5   1    1
# 1      202204100BRK  hieldbu01        1  35:53   8   23    5    14   0    0
# 2      202204100BRK  brissos01        1  35:47  10   20    5    10   3    4
# 3      202204100BRK  jacksis01        1  32:01   3    4    0     0   1    2
# 4      202204100BRK  mccontj01        1  30:52   5   15    3     7   1    2
# ...             ...        ...      ...    ...  ..  ...  ...   ...  ..  ...
# 31603  202201130NOP  gabriwe01        0   4:26   1    1    1     1   0    0
# 31604  202201150SAS  gabriwe01        0   0:00   0    0    0     0   0    0
# 31605  202112220SAC  wrighmo01        0   1:28   0    0    0     0   0    0
# 31606  202112260LAC  wrighmo01        0   0:00   0    0    0     0   0    0
# 31607  202112270LAC  wrighmo01        0   0:00   0    0    0     0   0    0
#
#        ...  tov  pf  pts  plus_minus  did_not_play  is_inactive  off_rtg  \
# 0      ...    1   0   17          -9             0            0      137
# 1      ...    2   3   21           0             0            0       94
# 2      ...    0   5   28          -9             0            0      137
# 3      ...    2   5    7           3             0            0       89
# 4      ...    0   3   14           7             0            0      104
# ...    ...  ...  ..  ...         ...           ...          ...      ...
# 31603  ...    2   2    3          -4             0            0       62
# 31604  ...    0   0    0           0             1            0        0
# 31605  ...    0   0    0           1             0            0      217
# 31606  ...    0   0    0           0             1            0        0
# 31607  ...    0   0    0           0             1            1        0
#
#        def_rtg   bpm          game_player_id
# 0          132   1.7  202204100BRK_halibty01
# 1          128  -2.3  202204100BRK_hieldbu01
# 2          133   4.4  202204100BRK_brissos01
# 3          128  -9.2  202204100BRK_jacksis01
# 4          126  -1.7  202204100BRK_mccontj01
# ...        ...   ...                     ...
# 31603      110  -6.4  202201130NOP_gabriwe01
# 31604        0   0.0  202201150SAS_gabriwe01
# 31605      103  24.4  202112220SAC_wrighmo01
# 31606        0   0.0  202112260LAC_wrighmo01
# 31607        0   0.0  202112270LAC_wrighmo01
#
# [31608 rows x 25 columns]

# %% [markdown]
# Our 3NF database has 4 tables (entities):

# %%
nba_game
# Out:
#             game_id   game_date  OT
# 0      202204100BRK  2022-04-10   0
# 25     202204100CHO  2022-04-10   0
# 52     202204100CLE  2022-04-10   0
# 77     202204100DAL  2022-04-10   0
# 103    202204100DEN  2022-04-10   1
# ...             ...         ...  ..
# 19708  202110300MIN  2021-10-30   0
# 19726  202112150DEN  2021-12-15   0
# 19748  202202010MIN  2022-02-01   0
# 20615  202203270BOS  2022-03-27   0
# 20679  202112270MIN  2021-12-27   0
#
# [1230 rows x 3 columns]

# %%
nba_player
# Out:
#        player_id             player
# 0      halibty01  Tyrese Haliburton
# 1      hieldbu01        Buddy Hield
# 2      brissos01     Oshae Brissett
# 3      jacksis01     Isaiah Jackson
# 4      mccontj01     T.J. McConnell
# ...          ...                ...
# 31515  garrema01     Marcus Garrett
# 31535  chalmma01     Mario Chalmers
# 31538  holmaar01        Aric Holman
# 31540  scrubja01         Jay Scrubb
# 31590  prestja01      Jason Preston
#
# [621 rows x 2 columns]

# %%
nba_teamgame
#primary key here is superkey, which is game_id + Team_Abbrev
# Out:
#             game_id H_A Team_Abbrev  Team_Score  Team_pace  Team_efg_pct  \
# 0      202204100BRK   A         IND         126      103.9         0.543
# 12     202204100BRK   H         BRK         134      103.9         0.691
# 25     202204100CHO   A         WAS         108       97.7         0.489
# 37     202204100CHO   H         CHO         124       97.7         0.640
# 52     202204100CLE   A         MIL         115      101.9         0.511
# ...             ...  ..         ...         ...        ...           ...
# 21491  202112190MIN   H         MIN         111       91.8         0.565
# 21492  202112210DAL   A         MIN         102       93.9         0.538
# 21629  202112280MIN   H         MIN          88       93.1         0.441
# 21708  202112230UTA   A         MIN         116      102.1         0.530
# 21709  202112270MIN   H         MIN         108       99.0         0.522
#
#        Team_tov_pct  Team_orb_pct  Team_ft_rate  Team_off_rtg Opponent_Abbrev
# 0               5.9          20.8         0.125         121.3             BRK
# 12             17.9          29.6         0.272         129.0             IND
# 25              8.7          31.5         0.170         110.5             CHO
# 37             15.2          29.7         0.112         126.9             WAS
# 52             10.5          17.4         0.284         112.9             CLE
# ...             ...           ...           ...           ...             ...
# 21491           9.0          15.0         0.312         120.9             DAL
# 21492          16.2          20.9         0.215         108.6             DAL
# 21629           9.6          20.4         0.153          94.5             NYK
# 21708          11.6          30.0         0.089         113.7             UTA
# 21709          12.5          22.4         0.156         109.1             BOS
#
# [2460 rows x 11 columns]

# %%
nba_playergame
# Out:
#             game_id  player_id  starter     mp  fg  fga  fg3  fg3a  ft  fta  \
# 0      202204100BRK  halibty01        1  39:28   7   14    2     5   1    1
# 1      202204100BRK  hieldbu01        1  35:53   8   23    5    14   0    0
# 2      202204100BRK  brissos01        1  35:47  10   20    5    10   3    4
# 3      202204100BRK  jacksis01        1  32:01   3    4    0     0   1    2
# 4      202204100BRK  mccontj01        1  30:52   5   15    3     7   1    2
# ...             ...        ...      ...    ...  ..  ...  ...   ...  ..  ...
# 31603  202201130NOP  gabriwe01        0   4:26   1    1    1     1   0    0
# 31604  202201150SAS  gabriwe01        0   0:00   0    0    0     0   0    0
# 31605  202112220SAC  wrighmo01        0   1:28   0    0    0     0   0    0
# 31606  202112260LAC  wrighmo01        0   0:00   0    0    0     0   0    0
# 31607  202112270LAC  wrighmo01        0   0:00   0    0    0     0   0    0
#
#        ...  tov  pf  pts  plus_minus  did_not_play  is_inactive  off_rtg  \
# 0      ...    1   0   17          -9             0            0      137
# 1      ...    2   3   21           0             0            0       94
# 2      ...    0   5   28          -9             0            0      137
# 3      ...    2   5    7           3             0            0       89
# 4      ...    0   3   14           7             0            0      104
# ...    ...  ...  ..  ...         ...           ...          ...      ...
# 31603  ...    2   2    3          -4             0            0       62
# 31604  ...    0   0    0           0             1            0        0
# 31605  ...    0   0    0           1             0            0      217
# 31606  ...    0   0    0           0             1            0        0
# 31607  ...    0   0    0           0             1            1        0
#
#        def_rtg   bpm          game_player_id
# 0          132   1.7  202204100BRK_halibty01
# 1          128  -2.3  202204100BRK_hieldbu01
# 2          133   4.4  202204100BRK_brissos01
# 3          128  -9.2  202204100BRK_jacksis01
# 4          126  -1.7  202204100BRK_mccontj01
# ...        ...   ...                     ...
# 31603      110  -6.4  202201130NOP_gabriwe01
# 31604        0   0.0  202201150SAS_gabriwe01
# 31605      103  24.4  202112220SAC_wrighmo01
# 31606        0   0.0  202112260LAC_wrighmo01
# 31607        0   0.0  202112270LAC_wrighmo01
#
# [31608 rows x 25 columns]

# %%
nba_db = sqlite3.connect("nba.db")

# %%
nba_game.to_sql('games', nba_db, index=False, chunksize=1000, if_exists='replace')
nba_playergame.to_sql('player_game', nba_db, index=False, chunksize=1000, if_exists='replace')
nba_teamgame.to_sql('team_game', nba_db, index=False, chunksize=1000, if_exists='replace')
nba_player.to_sql('players', nba_db, index=False, chunksize=1000, if_exists='replace')
# Out:
# 621

# %%
myquery = '''
select * 
from team_game
where Team_Abbrev like '%CL%' and Team_Score > 120
'''
pd.read_sql(myquery, nba_db)
# Out:
#         game_id H_A Team_Abbrev  Team_Score  Team_pace  Team_efg_pct  \
# 0  202204100CLE   H         CLE         133      101.9         0.644
# 1  202203080IND   A         CLE         127       98.2         0.542
# 2  202110200MEM   A         CLE         121      101.1         0.581
# 3  202111070NYK   A         CLE         126       96.4         0.650
# 4  202112100MIN   A         CLE         123      103.6         0.618
# 5  202112150CLE   H         CLE         124       96.4         0.675
# 6  202112260CLE   H         CLE         144      107.2         0.632
# 7  202202280CLE   H         CLE         122       96.8         0.628
#
#    Team_tov_pct  Team_orb_pct  Team_ft_rate  Team_off_rtg Opponent_Abbrev
# 0           9.0          23.3         0.128         130.5             MIL
# 1           6.1          33.3         0.253         129.4             IND
# 2           9.0          14.9         0.140         119.7             MEM
# 3          13.7          30.6         0.100         130.7             NYK
# 4          13.7          16.7         0.212         118.7             MIN
# 5          14.2          22.5         0.200         128.7             HOU
# 6           9.7          28.9         0.094         134.4             TOR
# 7          18.4          30.3         0.392         126.0             MIN

# %%
nba_playergame.columns
# Out:
# Index(['game_id', 'player_id', 'starter', 'mp', 'fg', 'fga', 'fg3', 'fg3a',
#        'ft', 'fta', 'orb', 'drb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts',
#        'plus_minus', 'did_not_play', 'is_inactive', 'off_rtg', 'def_rtg',
#        'bpm', 'game_player_id'],
#       dtype='object')
